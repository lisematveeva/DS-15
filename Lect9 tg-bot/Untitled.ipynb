# %%
import telebot
from telebot import types


from bot_token import token
bot = telebot.TeleBot(token)

# %%
@bot.message_handler(commands=['start']) #декоратор 
def send_keyboard(message, text="Привет, чем я могу тебе помочь?"):
    keyboard = types.ReplyKeyboardMarkup(row_width=2)  
    itembtn1 = types.KeyboardButton('История') 
    itembtn2 = types.KeyboardButton('Волатильность')
    itembtn3 = types.KeyboardButton('Доходность')
    #itembtn4 = types.KeyboardButton("Ребалансировка")
    itembtn5 = types.KeyboardButton('Инструкция')
    keyboard.add(itembtn1, itembtn2)
    keyboard.add(itembtn3, itembtn5, ) 

    # возврат клаиатуры
    msg = bot.send_message(message.from_user.id,
                     text=text, reply_markup=keyboard)

 
    bot.register_next_step_handler(msg, callback_worker)
    
bot.polling(none_stop=True)
# Out:
# 2024-01-16 23:30:02,932 (__init__.py:1083 MainThread) ERROR - TeleBot: "Threaded polling exception: A request to the Telegram API was unsuccessful. Error code: 409. Description: Conflict: can't use getUpdates method while webhook is active; use deleteWebhook to delete the webhook first"
# 2024-01-16 23:30:02,932 (__init__.py:1085 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\elgol\anaconda3\lib\site-packages\telebot\__init__.py", line 1073, in __threaded_polling
#     polling_thread.raise_exceptions()
#   File "C:\Users\elgol\anaconda3\lib\site-packages\telebot\util.py", line 108, in raise_exceptions
#     raise self.exception_info
#   File "C:\Users\elgol\anaconda3\lib\site-packages\telebot\util.py", line 90, in run
#     task(*args, **kwargs)
#   File "C:\Users\elgol\anaconda3\lib\site-packages\telebot\__init__.py", line 649, in __retrieve_updates
#     updates = self.get_updates(offset=(self.last_update_id + 1),
# ...
